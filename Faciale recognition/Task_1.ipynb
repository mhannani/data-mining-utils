# %%
import matplotlib.pyplot as plt
from loaders import load_olivetti

# %%
faces_data, faces_images = load_olivetti()

# %%
faces_data
# Out:
# array([[0.30991736, 0.3677686 , 0.41735536, ..., 0.15289256, 0.16115703,
#         0.1570248 ],
#        [0.45454547, 0.47107437, 0.5123967 , ..., 0.15289256, 0.15289256,
#         0.15289256],
#        [0.3181818 , 0.40082645, 0.49173555, ..., 0.14049587, 0.14876033,
#         0.15289256],
#        ...,
#        [0.5       , 0.53305787, 0.607438  , ..., 0.17768595, 0.14876033,
#         0.19008264],
#        [0.21487603, 0.21900827, 0.21900827, ..., 0.57438016, 0.59090906,
#         0.60330576],
#        [0.5165289 , 0.46280992, 0.28099173, ..., 0.35950413, 0.3553719 ,
#         0.38429752]], dtype=float32)

# %%
faces_data.shape
# Out:
# (400, 4096)

# %%
faces_images.shape
# Out:
# (400, 64, 64)

# %%
from visualizer import show_some_images

# %%
show_some_images(faces_images)

# %%
from image_manipulation import psi

# %%
plt.imshow(psi(faces_data).reshape(64, 64))

# %%
from image_manipulation import calculate_phi

# %%
phi = calculate_phi(faces_data)

# %%
phi = phi.reshape(400, 64, 64)

# %%
show_some_images(phi)
