# %% [markdown]
# ## 1. Load images from the olivetti dataset

# %%
import matplotlib.pyplot as plt
from loaders import load_olivetti

# %%
faces_data, faces_images = load_olivetti()

# %%
faces_data[:2]
# Out:
# array([[0.30991736, 0.3677686 , 0.41735536, ..., 0.15289256, 0.16115703,
#         0.1570248 ],
#        [0.45454547, 0.47107437, 0.5123967 , ..., 0.15289256, 0.15289256,
#         0.15289256]], dtype=float32)

# %%
faces_data.shape
# Out:
# (400, 4096)

# %%
faces_images.shape
# Out:
# (400, 64, 64)

# %%
from visualizer import show_some_images

# %%
show_some_images(faces_images)
